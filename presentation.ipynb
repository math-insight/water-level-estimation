# %% [markdown]
# # Estymacja poziomu wody w Odrze na wysokości Głogowa

# %% [markdown]
# ## Mapa przedstawiająca stacje hydrologiczne i meteorologiczne na Odrze i jej dopływach.

# %%
from IPython.display import display, Image

display(Image(filename='./imgw-map.png'))

# %%
import pandas

types = {'Station': 'str', 'ID': 'str', 'River': 'str'}
stations = pandas.read_csv('./stations.csv', delimiter=',', names=['Station', 'ID', 'River'], dtype=types)

stations
# Out:
#           Station         ID        River
# 0          GŁOGÓW  151160060         Odra
# 1          OSETNO  151160140       Barycz
# 2       KORZENSKO  151160200         Orla
# 3   KANCLERZOWICE  151160220  Sasiecznica
# 4            ŁĄKI  151170040       Barycz
# ..            ...        ...          ...
# 74        BOJANÓW  150180040        Psina
# 75   KRZYŻANOWICE  149180010         Odra
# 76           OLZA  149180300         Odra
# 77       CHAŁUPKI  149180020         Odra
# 78        ŁAZISKA  149180030         Olza
#
# [79 rows x 3 columns]
